# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pickle

# %%
df = pd.DataFrame(pd.read_pickle('C:\\Users\\Ege\\Desktop\\bigger-fish\\testimage2_new.pkl', compression=None)[0])

# %%
df = df.T
df['TIME'] = df.index
df.rename(columns = {0:'LOOP_COUNT'}, inplace=True)

# %%
df
# Out:
#       LOOP_COUNT  TIME
# 0          83747     0
# 1             -1     1
# 2             -1     2
# 3             -1     3
# 4             -1     4
# ...          ...   ...
# 4995          -1  4995
# 4996          -1  4996
# 4997          -1  4997
# 4998          -1  4998
# 4999          -1  4999
#
# [5000 rows x 2 columns]

# %%
plt.rcParams['figure.figsize'] = (20,10)

# %%
plt.scatter(df['TIME'], df['LOOP_COUNT'], s = 1, c = "black")

# %%
import numpy as np
plt.rcParams['figure.figsize'] = (32,4)

#df['LOOP_COUNT'] = (df['LOOP_COUNT']/df['LOOP_COUNT'].max())*100

x = df['TIME']#np.linspace(0,15)
y = df['LOOP_COUNT']

fig, (ax, ax2) = plt.subplots(nrows=2, sharex=True)
extent = [0,5,0,df['LOOP_COUNT'].max()]
ax.imshow(y[np.newaxis,:], cmap="plasma", aspect="auto", extent=extent)
ax2.imshow(df[df['LOOP_COUNT'] > 0]['LOOP_COUNT'][np.newaxis,:], cmap="plasma", aspect="auto", extent=extent)
#ax2.scatter(df['TIME'], df['LOOP_COUNT'], lw=0.2)
# Out:
# C:\Anaconda3\envs\bigggerfishenv\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Anaconda3\envs\bigggerfishenv\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   if sys.path[0] == '':
